# %%
import sys

sys.path.append('../../')  # Add the path to the my_packages module
from my_packages.db_service.error_service import delete_error_docs, errors_to_df, pretty_print_errors
from my_packages.evaluation.midio_compiler import compile_code
from my_packages.db_service.experiment_service import experiment_exists, pretty_print_experiment_collections, run_experiment_quality_checks, setup_experiment_collection
import os

# Use a different database for the error messages
# os.environ["EXPERIMENT_DB_NAME"] = "error_msgs"
"Expected token Identifier, but got Keyword(Trigger) at 1572, ERROR compiler::frontend::parser: 1373:     backtrace: disabled backtrace]       "

"""
import("std", Std_k98ojb)
import("http", Http_q7o96c)

module() main {
    func(doc: "calculate the product of the unique numbers in a given list.") unique_product {
        in(x: -324, y: 105, name: "list") property(List) list_8d6a1b

        out(x: 796, y: 110, name: "product") property(Number) product_3f4c3e

        instance(x: -21, y: 105) unique_422795 root.Std_k98ojb.Iteration.Reduce {}
        instance(x: 60, y: 105) mul_4a3d32 root.Std_k98ojb.Math.Mul {}
        list_8d6a1b -> unique_422795.items
        1 -> unique_422795.initial_value
        func() {
            in(x: -10, y: 105, name: "acc") property(Number) acc_3c7f8d
            in(x: -10, y: 165, name: "item") property(Number) item_4b2a9e

            out(x: 210, y: 105, name: "") property(Number) _7973c8

            instance(x: 100, y: 135) contains_6d2f9c root.Std_k98ojb.List.Contains {}
            instance(x: 40, y: 105) add_8a7e3c root.Std_k98ojb.Math.Add {}
            instance(x: 100, y: 105) listadd_26d6f6 root.Std_k98ojb.List.Add {}
            data_instance(x: -40, y: 135) data_a7a7e1  = []
            instance(x: 100, y: 105) mul_4a3d32 root.Std_k98ojb.Math.Mul {}
            contains_6d2f9c.list -> add_8a7e3c.first
            contains_6d2f9c.is_contained -> ifexpression_3d7de6.value
            data_a7a7e1 -> contains_6d2f9c.list
            item_4b2a9e -> contains_6d2f9c.item
            0 -> add_8a7e3c.second
            acc_3c7f8d -> mul_4a3d32.first
            ifexpression_3d7de6.then -> add_8a7e3c.execute
            ifexpression_3d7de6.else -> listadd_26d6f6.trigger
            item_4b2a9e -> mul_4a3d32.second
            listadd_26d6f6.item -> contains_6d2f9c.list
            listadd_26d6f6.listWithItem -> ifexpression_3d7de6.gen_0
            item_4b2a9e -> listadd_26d6f6.item
            mul_4a3d32.result -> _7973c8
        } -> unique_422795.handler
        unique_422795.accumulator -> product_3f4c3e
    }

    

    instance(x: -106, y: 10) unique_product_a2b59d root.main.unique_product {}
} 
"""
experiment_name = f"regular_coverage_5_shot"

pretty_print_errors(experiment_name, limit=21, filter={"eval_method": "3_fold"})
# delete_error_docs(experiment_name, filter={"eval_method": "hold_out"})
# pretty_print_experiment_collections(experiment_name, filter={"eval_method": ""})
# errors_to_df(experiment_name)
# pretty_print_experiment_collections(experiment_name, filter={"eval_method": "hold_out"})
# Out:
# task_id metric error_type                                                                                                                                                                                                                                        error_msg                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            
# ...

# %%
sys.path.append('../../')  # Add the path to the my_packages module
from my_packages.db_service.data_visualization import visualize_error_flow_for_model



# Assuming the experiment 'GPT4_signature_exp1' exists,
# and you evaluated 100 candidates for model 'GPT-4':
# visualize_error_flow_for_model(experiment_name, "gpt-4o")
pretty_print_experiment_collections(experiment_name, filter={"eval_method": "hold_out"})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 sys.path.append('../../')  # Add the path to the my_packages module
#       2 from my_packages.db_service.data_visualization import visualize_error_flow_for_model
#       6 # Assuming the experiment 'GPT4_signature_exp1' exists,
#       7 # and you evaluated 100 candidates for model 'GPT-4':
#       8 # visualize_error_flow_for_model(experiment_name, "gpt-4o")
#
# NameError: name 'sys' is not defined
