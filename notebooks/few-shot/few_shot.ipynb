# %% [markdown]
# # Install dependencies

# %%
# # For Notebook:
# %pip install ollama
# %pip install openai
# %pip install anthropic
# %pip install transformers
# %pip install tiktoken
# %pip install python-dotenv
# %pip install colorama


# # For packages: 
# %pip install scikit-learn
# %pip install matplotlib
# %pip install numpy
# %pip install pandas
# %pip install iterative-stratification
# %pip install evaluate

# # For WebUI testing:
# %pip install open-webui

# %% [markdown]
# # Prepare data

# %%
import sys
sys.path.append('../../')  # Add the path to the my_packages module
from my_packages.data_processing.split_dataset import split_on_shots, read_dataset_to_json
from my_packages.data_processing.get_labels_data import used_libraries_from_dataset, used_libraries_to_string
from my_packages.analysis.analyze_datasets import analyze_library_distribution, analyze_instance_distribution, analyze_visual_node_types_distribution

main_dataset_folder = '../../data/mbpp_transformed_code_examples/sanitized-MBPP-midio.json'
DATA_DIR = '../../data/mbpp_transformed_code_examples/only_files'

dataset = read_dataset_to_json(main_dataset_folder)
    
num_shot = 5 # Few-shot examples
eval_size_percentage = 0.5

train_data, val_data, test_data = split_on_shots(num_shot, eval_size_percentage, dataset, seed = 64, write_to_file=True)

# Extract all unique nodes (library_functions) across datasets
used_libraries_json = used_libraries_from_dataset(train_data)
explained_used_libraries = used_libraries_to_string(used_libraries_json)

#Bar chart of distribuation
# analyze_library_distribution(train_data, val_data, test_data)
# analyze_instance_distribution(train_data, val_data, test_data)
# analyze_visual_node_types_distribution(train_data, val_data, test_data)
# Out:
# 6
# 3
# 3
# Training set size: 5
# Validation set size: 3
# Test set size: 3
# Library functions included in the dataset: 21

# %% [markdown]
# # Prepare prompts

# %%
from my_packages.prompting.few_shot import split_and_format

train_prompts, train_responses = split_and_format(train_data,"CODE_TEMPLATE",'../../data/mbpp_transformed_code_examples/only_files/')
val_prompts, val_responses = split_and_format(val_data,"CODE_TEMPLATE", '../../data/mbpp_transformed_code_examples/only_files/')
test_prompts, test_responses = split_and_format(test_data ,"CODE_TEMPLATE", '../../data/mbpp_transformed_code_examples/only_files/')

# %% [markdown]
# # Init model provider

# %%
import os
import ollama
from openai import OpenAI
from anthropic import Anthropic
from dotenv import load_dotenv
from my_packages.prompting.few_shot import create_few_shot_messages
from my_packages.utils.tokens_utils import write_models_code_tokens_to_file, models_not_in_file
from my_packages.utils.server_utils import server_diagnostics, is_remote_server_reachable

model_provider = 'ollama'

match model_provider:
    case 'ollama':
        host = 'http://localhost:11434'
        if is_remote_server_reachable(url = host + "/api/tags"):
            print("Server is reachable.")
        else:
            server_diagnostics()
            print("Ollama server is not reachable. Batch job might have finished. Try running bash script again.")

        embed_client = OpenAI(
            base_url=host+'/v1/',
            api_key='ollama',
        )
        client = ollama.Client(
            host=host,
        )
        models = [
            #14b models:
            "phi4:14b-fp16",
            # "qwen2.5:14b-instruct-fp16",
            # #32b models:
            # "qwq:32b-preview-fp16",
            # "qwen2.5-coder:32b-instruct-fp16",
            # #70b models:
            # "llama3.3:70b-instruct-fp16", 
            # "qwen2.5:72b-instruct-fp16",
            #ollama rm llama3.1:8b-instruct-fp16
        ]
        few_shot_messages = create_few_shot_messages(explained_used_libraries, train_prompts, train_responses, "CODE_GENERATOR_TEMPLATE", "system")
        models_not_tokenized = models_not_in_file(models, 'code_max_tokens.json')
        write_models_code_tokens_to_file(embed_client, models_not_tokenized, DATA_DIR, 'code_max_tokens.json')
        
    case 'openai':
        load_dotenv("../.env")
        openai_token = os.getenv('OPENAI_API_KEY')
        few_shot_messages = create_few_shot_messages(explained_used_libraries, train_prompts, train_responses, "CODE_GENERATOR_TEMPLATE", "developer")
        if not openai_token:
            raise Exception("OpenAI API key not found in .env file")
        client = OpenAI(api_key=openai_token)
        models = [
            "gpt-4o",
            # "o1-preview", 
        ]
        models_not_tokenized = models_not_in_file(models, 'code_max_tokens.json')
        write_models_code_tokens_to_file(client, models_not_tokenized, DATA_DIR, 'code_max_tokens.json')

    case 'anthropic':
        load_dotenv("../.env")
        anthropic_token = os.getenv('ANTHROPIC_API_KEY')
        if not anthropic_token:
            raise Exception("Anthropic API key not found in .env file")
        client = Anthropic(api_key=anthropic_token)
        models = [
            "claude-3-5-sonnet-20241022" #latest
        ]
        few_shot_messages = create_few_shot_messages(explained_used_libraries, train_prompts, train_responses, "CODE_GENERATOR_TEMPLATE", "system")
        models_not_tokenized = models_not_in_file(models, 'code_max_tokens.json')
        write_models_code_tokens_to_file(client, models_not_tokenized, DATA_DIR, 'code_max_tokens.json')
        
    case _:
        raise Exception("Model provider not supported")
# Out:
# Server is reachable.

# %%
import numpy as np
print(np.array([0.279,0.22, 0.22]).mean())
# Out:
# 0.23966666666666667

# %% [markdown]
# ## Evalaution

# %%
from my_packages.evaluation.code_evaluation import Run, calculate_final_result, run_testing, run_validation
from my_packages.utils.tokens_utils import get_model_code_tokens_from_file
from colorama import Fore, Back, Style

results = {}
for model_name in models:
    print(f"Model: {model_name}")
    model = get_model_code_tokens_from_file(model_name, 'code_max_tokens.json')

    validation_result = None
    validation_result = {
        "seed": None,
        "val_f1": 0.56,
        "val_pass_ks": {"pass@1": 0.3},
        "temperature": 0.2,
        "top_p": 0.8,
    }
    validation_result = Run(
        phase="validation",
        temperature=0.5,
        top_p=0.5,
        top_k=0.5,
        metric_results={f"pass@k_semantic": {"pass@1": 0.5}},
        seed=9
    )

    if validation_result == None:
        validation_result = run_validation(
            client,
            few_shot_messages,
            model,
            val_prompts,
            val_responses,
            temperatures=[0.2, 0.6, 0.9],
            top_ps=[0.2, 0.6, 0.9],
            top_ks=[10, 50, 100],
            ks=[1],
            seed=9,
            debug=True,
            optimizer_metric="semantic", # "semantic"  "syntax", "tests" or "all"
        )
    validation_result.print()

    test_results = run_testing(
        client,
        few_shot_messages,
        model,
        test_prompts,
        test_responses,
        temperature=validation_result.temperature,
        top_p=validation_result.top_p,
        top_k=validation_result.top_k,
        ks=[1, 5], # k generations per task
        seeds=[3, 75, 346],
        debug=True,
        metrics=["syntax", "semantic"] # current metrics: "semantic",  "syntax", "tests"
    )
    results[model["name"]] = (validation_result, test_results)
      
# Print the final results
print("\nFINAL RESULTS:")
for model_name, (val_run, test_runs) in results.items():
    print(f"{Style.BRIGHT}{Fore.CYAN} Model: {model_name} {Style.RESET_ALL}")
    val_run.print()
    for test_run in test_runs:
        test_run.print()
    
    result_run = calculate_final_result(test_runs)
    result_run.print()
# Out:
# Model: phi4:14b-fp16
#
# ===  VALIDATION ===
#   > Temperature: 0.50
#   > Top_k: 0.50
#   > Top_p: 0.50
#   > Optimized metric result:: {
#     "pass@k_semantic": {
#         "pass@1": 0.5
#     }
# }
# Testing Phase:
#
# Generating response for sample 0..
#
# === Sample: 0 ===
#  User prompt:
# You are an expert Midio code programmer. Genereate the code for the following task:
# Create a flow to multiply two numbers.
#
# You must return the code in the following form:
#
# ```midio
#
#     //Midio Code
#
# ```
#
#  Assistant response: #1:
# import("std", Std_k98ojb)
# import("http", Http_q7o96c)
#
# module() main {
#     func(doc: "Multiplies two numbers.") multiply {
#         in(x: -56.1, y: 74.8, name: "num1") property(Number) num1_0e9a4f
#         in(x: -54.6, y: -52.2, name: "num2") property(Number) num2_b7c0d5
#         in(x: 3.7, y: -13.8, name: "execute") trigger() execute_92b2e1
#
#         out(x: 91.4, y: -21.6, name: "continue") trigger() continue_ea1f50
#         out(x: 96.5, y: 78.3, name: "output") property(Number) output_9d0c8b
#
#         instance(x: 26.2, y: -23.4) mul_faa6a7 root.Std_k98ojb.Math.Mul {}
#         num1_0e9a4f -> mul_faa6a7.first
#         num2_b7c0d5 -> mul_faa6a7.second
#         execute_92b2e1 -> mul_faa6a7.execute
#         mul_faa6a7.result -> output_9d0c8b
#         mul_faa6a7.done -> continue_ea1f50
#     }
#
#
#     instance(x: 41.4, y: -26.5) multiply_12e3f2 root.main.multiply {}
# }
#
#  Assistant response: #2:
# import("std", Std_k98ojb)
# import("http", Http_q7o96c)
#
# module() main {
#     func(doc: "Multiplies two numbers.") multiply {
#         in(x: -113, y: 62.5, name: "first") property(Number) first_1d4f8a
#         in(x: 483, y: -328, name: "second") property(Number) second_6e3c9b
#         in(x: 483, y: -328, name: "execute") trigger() execute_ba27ec
#
#         out(x: 1453, y: 319, name: "output") property(Number) output_e8d7f2
#         out(x: 1491, y: -61, name: "continue") trigger() continue_0e2b9c
#
#         instance(x: 841, y: -275) mul_9e1a23 root.Std_k98ojb.Math.Mul {}
#         getter(x: 1086, y: 278, name: "getter_4e1d42") getter_4e1d42 = result
#         first_1d4f8a -> mul_9e1a23.first
#         second_6e3c9b -> mul_9e1a23.second
#         execute_ba27ec -> mul_9e1a23.execute
#         getter_4e1d42.value -> output_e8d7f2
#         mul_9e1a23.result -> continue_0e2b9c
#     }
#
#
#     instance(x: -234.9000000000001, y: 114.14999999999998) multiply_870d80 root.main.multiply {}
#
# }
#
#  Assistant response: #3:
# import("std", Std_k98ojb)
# import("http", Http_q7o96c)
#
# module() main {
#     func(doc: "Multiplies two numbers.") multiply {
#         in(x: -99, y: 49.5, name: "first") property(Number) first_2d1e6f
#         in(x: -44, y: -110.5, name: "second") property(Number) second_7b6c3a
#         in(x: 31, y: -54, name: "execute") trigger() execute_e9b0cc
#
#         out(x: 172.5, y: -108.25, name: "continue") trigger() continue_4d2e01
#         out(x: 113.5, y: 52.75, name: "output") property(Number) output_c8a1c6
#
#         instance(x: 45.5, y: -116.5) mul_d3b7c0 root.Std_k98ojb.Math.Mul {}
#         execute_e9b0cc -> mul_d3b7c0.execute
#         first_2d1e6f -> mul_d3b7c0.first
#         second_7b6c3a -> mul_d3b7c0.second
#         mul_d3b7c0.result -> output_c8a1c6
#         mul_d3b7c0.done -> continue_4d2e01
#     }
#
#
#     instance(x: 124.5, y: -36) multiply_8a7f9e root.main.multiply {}
# }
#
#  Assistant response: #4:
# import("std", Std_k98ojb)
# import("http", Http_q7o96c)
#
# module() main {
#     func(doc: "Multiplies two numbers.") multiply {
#         in(x: -18, y: 15, name: "first") property(Number) first_1f6a9d
#         in(x: -12, y: -11, name: "second") property(Number) second_4a8c0b
#         in(x: 13, y: -21, name: "execute") trigger() execute_e7e7ad
#
#         out(x: 119.5, y: -15.25, name: "continue") trigger() continue_1e12d3
#         out(x: 124.75, y: 16.25, name: "output") property(Number) output_4c8f74
#
#         instance(x: 90.66666666666666, y: -14.333333333333329) mul_2a1e0d root.Std_k98ojb.Math.Mul {}
#         execute_e7e7ad -> mul_2a1e0d.execute
#         first_1f6a9d -> mul_2a1e0d.first
#         second_4a8c0b -> mul_2a1e0d.second
#         mul_2a1e0d.result -> output_4c8f74
#         mul_2a1e0d.done -> continue_1e12d3
#     }
#
#
#     instance(x: 145.66666666666666, y: -26.333333333333332) multiply_6b7ee5 root.main.multiply {}
# }
#
#  Assistant response: #5:
# import("std", Std_k98ojb)
# import("http", Http_q7o96c)
#
# module() main {
#     func(doc: "Multiplies two numbers.") multiply {
#         in(x: -32, y: 25, name: "first") property(Number) first_4a3f1e
#         in(x: -12, y: -34, name: "second") property(Number) second_f6d0c8
#         in(x: 47, y: -41, name: "execute") trigger() execute_5f44b2
#
#         out(x: 114.5, y: -27.25, name: "continue") trigger() continue_7a3e08
#         out(x: 105.75, y: 36.75, name: "output") property(Number) output_4d2c8b
#
#         instance(x: 34.5, y: -33.25) mul_0e6f9e root.Std_k98ojb.Math.Mul {}
#         first_4a3f1e -> mul_0e6f9e.first
#         second_f6d0c8 -> mul_0e6f9e.second
#         execute_5f44b2 -> mul_0e6f9e.execute
#         mul_0e6f9e.result -> output_4d2c8b
#         mul_0e6f9e.done -> continue_7a3e08
#     }
#
#
#     instance(x: 59.75, y: -10) multiply_c5d46d root.main.multiply {}
# }
#
#  True response:
#  import("std", Std_k98ojb)
# import("http", Http_q7o96c)
#
# module() main {
#     instance(x: -85.77739697265622, y: -46.66654199218749, name: "multiply_int") expression_3e25a9 root.Std_k98ojb.Math.Expression {
#         expression: "x * y"
#     }
# }
#
# Generating response for sample 1..
#
# === Sample: 1 ===
#  User prompt:
# You are an expert Midio code programmer. Genereate the code for the following task:
# create a flow find the dissimilar elements in the given two lists.
#
# You must return the code in the following form:
#
# ```midio
#
#     //Midio Code
#
# ```
#
#  Assistant response: #1:
# import("std", Std_k98ojb)
# import("http", Http_q7o96c)
#
# module() main {
#     func(doc: "Finds dissimilar elements in two given lists.") find_Dissimilar {
#         in(x: -1149.125, y: 461.25, name: "list1") property(List) list_7f5b8a
#         in(x: -1133.375, y: 699.75, name: "list2") property(List) list_e77d8c
#         in(x: -1174.125, y: 938.25, name: "execute") trigger() execute_1e9f68
#
#         out(x: 1373.5, y: 522.75, name: "continue") trigger() continue_f6b2a7
#         out(x: 1400.875, y: 760.125, name: "output") property(List) output_9c8d4f
#
#         instance(x: -1083.25, y: 1135.625, name: "difference1", instance_id: 2) difference_ba7e6b root.Std_k98ojb.Sets.Difference {}
#         instance(x: -1090.125, y: 1318.875, name: "difference2", instance_id: 3) difference_9e4f5d root.Std_k98ojb.Sets.Difference {}
#         instance(x: -1026.625, y: 1481.375, name: "concat", instance_id: 4) concat_f0a1c7 root.Std_k98ojb.List.Concat {}
#         instance(x: -1112.875, y: 1653.5, name: "execute1", instance_id: 6) execute_8d9f49 root.Std_k98ojb.Std.If {
#             then: "true"
#         }
#         instance(x: -1104.75, y: 1827.25, name: "execute2", instance_id: 7) execute_d5c1a0 root.Std_k98ojb.Std.If {
#             then: "true"
#         }
#
#         list_7f5b8a -> difference_ba7e6b.left
#         list_e77d8c -> difference_ba7e6b.right
#         difference_ba7e6b.difference -> execute_8d9f49.predicate
#         execute_1e9f68 -> execute_8d9f49.execute
#         execute_8d9f49.then -> difference_9e4f5d.left
#         list_e77d8c -> difference_9e4f5d.right
#         difference_ba7e6b.difference -> difference_9e4f5d.left
#         execute_1e9f68 -> execute_d5c1a0.execute
#         difference_9e4f5d.difference -> execute_d5c1a0.predicate
#         execute_d5c1a0.then -> concat_f0a1c7.right
#         difference_ba7e6b.difference -> concat_f0a1c7.left
#         concat_f0a1c7.result -> output_9c8d4f
#         execute_8d9f49.else -> execute_d5c1a0.execute
#         execute_8d9f49.else -> difference_9e4f5d.right
#         execute_d5c1a0.else -> concat_f0a1c7.left
#         execute_8d9f49.continue -> continue_f6b2a7
#         execute_d5c1a0.continue -> continue_f6b2a7
#     }
#
#
#     instance(x: 57.42772982007955, y: -40.38852907724322) find_Dissimilar_8d9f49 root.main.find_Dissimilar {}
# }
#
#  Assistant response: #2:
# import("std", Std_k98ojb)
# import("http", Http_q7o96c)
#
# module() main {
#     func(doc: "finds the dissimilar elements in the given two lists.") dissimilar_elements {
#         in(x: -166.66666666666669, y: 58.33333333333331, name: "list1") property(List) list_1_4f77c2
#         in(x: -166.66666666666669, y: -41.66666666666667, name: "list2") property(List) list_2_f5b0d7
#         in(x: 483, y: -328, name: "execute") trigger() execute_4e8f5a
#
#         out(x: 1453, y: 319, name: "output") property(List) output_1c2a9c
#         out(x: 1491, y: -61, name: "continue") trigger() continue_e5d7b6
#
#         instance(x: 49, y: -95) difference_f4f3e8 root.Std_k98ojb.Sets.Difference {}
#         instance(x: 268, y: -121) concat_9c2a65 root.Std_k98ojb.List.Concat {}
#         instance(x: 297, y: 38) difference_e1d5ef root.Std_k98ojb.Sets.Difference {}
#         getter(x: 1086, y: 278, name: "getter_c8f10e") getter_c8f10e = dissimilar
#         setter(x: 1081, y: -194, name: "setter_9a4c7d") setter_9a4c7d = dissimilar
#
#         list_1_4f77c2 -> difference_f4f3e8.left
#         list_2_f5b0d7 -> difference_f4f3e8.right
#         difference_f4f3e8.difference -> concat_9c2a65.left
#         list_2_f5b0d7 -> difference_e1d5ef.left
#         list_1_4f77c2 -> difference_e1d5ef.right
#         difference_e1d5ef.difference -> concat_9c2a65.right
#         concat_9c2a65.result -> getter_c8f10e.value
#         execute_4e8f5a -> setter_9a4c7d.execute
#         getter_c8f10e.value -> output_1c2a9c
#         setter_9a4c7d.continue -> continue_e5d7b6
#     }
#
#
#     instance(x: -234.9000000000001, y: 114.14999999999998) dissimilar_elements_6fbbdb root.main.dissimilar_elements {}
#
# }
#
#  Assistant response: #3:
# import("std", Std_k98ojb)
# import("http", Http_q7o96c)
#
# module() main {
#     func(doc: "Finds dissimilar elements in two given lists.") dissimilar_elements {
#         in(x: -149.5, y: 26.75, name: "list1") property(List) list_1_2_3
#         in(x: -44.25, y: 37.0, name: "list2") property(List) list_4_5_6
#
#         out(x: 1459.0, y: 12.75, name: "output") property(List) output_7_8_9
#         out(x: 1551.25, y: -23.0, name: "continue") trigger() continue_10_11_12
#
#         instance(x: 259.5, y: 40.0) difference_c2b4d root.Std_k98ojb.Sets.Difference {}
#         instance(x: 596.75, y: 26.25) difference_6e1f57 root.Std_k98ojb.Sets.Difference {}
#         instance(x: 864.5, y: -10.0) concat_8c3d4a root.Std_k98ojb.List.Concat {}
#
#         list_1_2_3 -> difference_c2b4d.left
#         list_4_5_6 -> difference_c2b4d.right
#         list_4_5_6 -> difference_6e1f57.left
#         list_1_2_3 -> difference_6e1f57.right
#
#         difference_c2b4d.difference -> concat_8c3d4a.left
#         difference_6e1f57.difference -> concat_8c3d4a.right
#
#         concat_8c3d4a.result -> output_7_8_9
#         concat_8c3d4a.result -> continue_10_11_12
#     }
#
#
#     instance(x: 17.25, y: -32.75) dissimilar_elements_a0e5a9 root.main.dissimilar_elements {}
# }
#
#  Assistant response: #4:
# import("std", Std_k98ojb)
# import("http", Http_q7o96c)
#
# module() main {
#     func(doc: "finds the dissimilar elements in the given two lists.") find_Dissimilar {
#         in(x: -113, y: 62.5, name: "list1") property(List) list_24e9a6
#         in(x: 483, y: -328, name: "execute") trigger() execute_fa8807
#         in(x: 1453, y: 319, name: "list2") property(List) list_25655e
#
#         out(x: 1491, y: -61, name: "continue") trigger() continue_aedf0f
#         out(x: 683.0457784343986, y: 73.83239411456998, name: "output") property(List) output_cffcc2
#
#         instance(x: 841, y: -275) add_9e1a23 root.Std_k98ojb.Math.Add {}
#         instance(x: 297, y: 38) difference_988da1 root.Std_k98ojb.Sets.Difference {}
#         instance(x: 268, y: -121) generaterange_578305 root.Std_k98ojb.List.GenerateRange {}
#         instance(x: 776, y: -147) if_f43197 root.Std_k98ojb.Std.If {}
#         setter(x: 1081, y: -194, name: "setter_8cdd78") setter_8cdd78 = dissimilar
#         setter(x: 1081, y: 53, name: "setter_9055a9") setter_9055a9 = dissimilar
#         getter(x: 1086, y: 278, name: "getter_4e1d42") getter_4e1d42 = dissimilar
#         instance(x: 697, y: 100) firstitem_5ed176 root.Std_k98ojb.List.FirstItem {}
#         instance(x: 557, y: -118) isempty_a948ab root.Std_k98ojb.List.IsEmpty {}
#         list_24e9a6 -> difference_988da1.left
#         list_25655e -> difference_988da1.right
#         difference_988da1.difference -> firstitem_5ed176.list
#         if_f43197.then -> setter_8cdd78.execute
#         if_f43197.else -> setter_9055a9.execute
#         execute_fa8807 -> if_f43197.execute
#         getter_4e1d42.value -> output_cffcc2
#         firstitem_5ed176.item -> setter_9055a9.new_value
#         setter_8cdd78.continue -> continue_aedf0f
#         setter_9055a9.continue -> continue_aedf0f
#         0 -> generaterange_578305.from
#         difference_988da1.difference -> generaterange_578305.list
#         generaterange_578305.list -> add_9e1a23.first
#         1 -> add_9e1a23.second
#         add_9e1a23.result -> setter_8cdd78.new_value
#         difference_988da1.difference -> isempty_a948ab.list
#         isempty_a948ab.isEmpty -> if_f43197.predicate
#     }
#
#
#     instance(x: -234.9000000000001, y: 114.14999999999998) find_dissimilar_870d80 root.main.find_Dissimilar {}
#
# }
#
#  Assistant response: #5:
# import("std", Std_k98ojb)
# import("http", Http_q7o96c)
#
# module() main {
#     func(doc: "finds the dissimilar elements in the given two lists.") dissimilar_elements {
#         in(x: -171.33333333333331, y: 114.66666666666669, name: "list1") property(List) list1_7e4a62
#         in(x: -151.66666666666666, y: -64.33333333333334, name: "list2") property(List) list2_e6f8c0
#         in(x: 3.999999999999986, y: -100.00000000000003, name: "execute") trigger() execute_7b9d40
#
#         out(x: 829.3333333333334, y: 75.66666666666663, name: "continue") trigger() continue_b8f3a2
#         out(x: 683.3333333333334, y: -64.00000000000006, name: "output") property(List) output_7c9d73
#
#         instance(x: 245.66666666666663, y: 38.66666666666667) difference_f6e2f0 root.Std_k98ojb.Sets.Difference {}
#         instance(x: 474.33333333333326, y: -101.66666666666669) concat_5c3a1d root.Std_k98ojb.List.Concat {}
#         instance(x: 691.6666666666666, y: 114.66666666666663) difference_8f9e0c root.Std_k98ojb.Sets.Difference {}
#
#         list1_7e4a62 -> concat_5c3a1d.left
#         list2_e6f8c0 -> concat_5c3a1d.right
#         concat_5c3a1d.result -> difference_f6e2f0.left
#         list2_e6f8c0 -> difference_f6e2f0.right
#         difference_f6e2f0.difference -> difference_8f9e0c.left
#         list1_7e4a62 -> difference_8f9e0c.right
#         difference_8f9e0c.difference -> output_7c9d73
#         execute_7b9d40 -> continue_b8f3a2
#     }
#
#
#     instance(x: 1692, y: 462) dissimilar_elements_d2b5c6 root.main.dissimilar_elements {}
# }
#
#  True response:
#  import("std", Std_k98ojb)
# import("http", Http_q7o96c)
#
# module() main {
#
#     instance(x: -55.55885498046882, y: 80.55560302734375) difference_1f4c9a root.Std_k98ojb.Sets.Difference {}
#
# }
#
# Generating response for sample 2..
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 44
#      28         validation_result = run_validation(
#      29             client,
#      30             few_shot_messages,
#    (...)
#      40             optimizer_metric="semantic", # "semantic"  "syntax", "tests" or "all"
#      41         )
#      42     validation_result.print()
# ---> 44     test_results = run_testing(
#      45         client,
#      46         few_shot_messages,
#      47         model,
#      48         test_prompts,
#      49         test_responses,
#      50         temperature=validation_result.temperature,
#      51         top_p=validation_result.top_p,
#      52         top_k=validation_result.top_k,
#      53         ks=[1, 5], # k generations per task
#      54         seeds=[3, 75, 346],
#      55         debug=True,
#      56         metrics=["syntax", "semantic"] # current metrics: "semantic",  "syntax", "tests"
#      57     )
#      58     results[model["name"]] = (validation_result, test_results)
#      60 # Print the final results
#
# File ~/Thesis_project/notebooks/few-shot/../../my_packages/evaluation/code_evaluation.py:338, in run_testing(client, messages, model, test_prompts, test_responses, temperature, top_p, top_k, ks, seeds, debug, metrics)
#     333 for seed in seeds:
#     334     print(f"\nTesting with Seed: {seed} ..", end="\r")
#     336     metric_results_lists = evaluate_code(
#     337         client,
# --> 338         messages,
#     339         model['name'],
#     340         test_prompts,
#     341         test_responses,
#     342         model["max_tokens"],
#     343         temperature,
#     344         top_p,
#     345         top_k,
#     346         seed,
#     347         ks,
#     348         debug,
#     349         evaluation_metric=metrics
#     350     )
#     352     new_run = Run(
#     353         phase="testing",
#     354         temperature=temperature,
#    (...)
#     363         seed=seed
#     364     )
#     366     results.append(new_run)
#
# File ~/Thesis_project/notebooks/few-shot/../../my_packages/evaluation/code_evaluation.py:231, in evaluate_code(client, messages, model, prompts, responses, max_new_tokens, temperature, top_p, top_k, seed, ks, debug, evaluation_metric)
#     216 def evaluate_code(
#     217     client,
#     218     messages,
#    (...)
#     229     evaluation_metric = ["syntax", "semantic", "tests"]
#     230 ):
# --> 231     model_result = run_model(
#     232         client,
#     233         messages,
#     234         model,
#     235         prompts,
#     236         responses,
#     237         max_new_tokens,
#     238         temperature,
#     239         top_p,
#     240         top_k,
#     241         ks,
#     242         seed,
#     243         debug
#     244     )
#     246     metric_results = []
#     247     for metric in evaluation_metric:
#
# File ~/Thesis_project/notebooks/few-shot/../../my_packages/evaluation/code_evaluation.py:181, in run_model(client, messages, model, prompts, responses, max_new_tokens, temperature, top_p, top_k, ks, seed, debug)
#     177         generated = invoke_openai_model(
#     178             client, full_prompt, model, max_new_tokens, temperature, top_p, top_k, seed=new_seed
#     179         )
#     180     else:
# --> 181         generated = invoke_ollama_model(
#     182             client, full_prompt, model, max_new_tokens, temperature, top_p, top_k, seed=new_seed
#     183         )
#     184     break  # If generation succeeded, break out of retry loop
#     185 except Exception as e:
#
# File ~/Thesis_project/notebooks/few-shot/../../my_packages/evaluation/models.py:38, in invoke_ollama_model(client, full_prompt, model, max_new_tokens, temperature, top_p, top_k, seed)
#      35 if seed:
#      36     kwargs['options']['seed'] = seed
# ---> 38 generated = client.chat(**kwargs)
#      40 filtered_generated = generated['message']['content'].replace("//", "").strip() # '//' outside main module can lead to compiler not ending properly
#      41 return filtered_generated
#
# File ~/Thesis_project/.venv_Master/lib/python3.11/site-packages/ollama/_client.py:332, in Client.chat(self, model, messages, tools, stream, format, options, keep_alive)
#     288 def chat(
#     289   self,
#     290   model: str = '',
#    (...)
#     297   keep_alive: Optional[Union[float, str]] = None,
#     298 ) -> Union[ChatResponse, Iterator[ChatResponse]]:
#     299   """
#     300   Create a chat response using the requested model.
#     301
#    (...)
#     330   Returns `ChatResponse` if `stream` is `False`, otherwise returns a `ChatResponse` generator.
#     331   """
# --> 332   return self._request(
#     333     ChatResponse,
#     334     'POST',
#     335     '/api/chat',
#     336     json=ChatRequest(
#     337       model=model,
#     338       messages=[message for message in _copy_messages(messages)],
#     339       tools=[tool for tool in _copy_tools(tools)],
#     340       stream=stream,
#     341       format=format,
#     342       options=options,
#     343       keep_alive=keep_alive,
#     344     ).model_dump(exclude_none=True),
#     345     stream=stream,
#     346   )
#
# File ~/Thesis_project/.venv_Master/lib/python3.11/site-packages/ollama/_client.py:177, in Client._request(self, cls, stream, *args, **kwargs)
#     173         yield cls(**part)
#     175   return inner()
# --> 177 return cls(**self._request_raw(*args, **kwargs).json())
#
# File ~/Thesis_project/.venv_Master/lib/python3.11/site-packages/ollama/_client.py:118, in Client._request_raw(self, *args, **kwargs)
#     117 def _request_raw(self, *args, **kwargs):
# --> 118   r = self._client.request(*args, **kwargs)
#     119   try:
#     120     r.raise_for_status()
#
# File ~/Thesis_project/.venv_Master/lib/python3.11/site-packages/httpx/_client.py:837, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     822     warnings.warn(message, DeprecationWarning)
#     824 request = self.build_request(
#     825     method=method,
#     826     url=url,
#    (...)
#     835     extensions=extensions,
#     836 )
# --> 837 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~/Thesis_project/.venv_Master/lib/python3.11/site-packages/httpx/_client.py:926, in Client.send(self, request, stream, auth, follow_redirects)
#     922 self._set_timeout(request)
#     924 auth = self._build_request_auth(request, auth)
# --> 926 response = self._send_handling_auth(
#     927     request,
#     928     auth=auth,
#     929     follow_redirects=follow_redirects,
#     930     history=[],
#     931 )
#     932 try:
#     933     if not stream:
#
# File ~/Thesis_project/.venv_Master/lib/python3.11/site-packages/httpx/_client.py:954, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     951 request = next(auth_flow)
#     953 while True:
# --> 954     response = self._send_handling_redirects(
#     955         request,
#     956         follow_redirects=follow_redirects,
#     957         history=history,
#     958     )
#     959     try:
#     960         try:
#
# File ~/Thesis_project/.venv_Master/lib/python3.11/site-packages/httpx/_client.py:991, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     988 for hook in self._event_hooks["request"]:
#     989     hook(request)
# --> 991 response = self._send_single_request(request)
#     992 try:
#     993     for hook in self._event_hooks["response"]:
#
# File ~/Thesis_project/.venv_Master/lib/python3.11/site-packages/httpx/_client.py:1027, in Client._send_single_request(self, request)
#    1022     raise RuntimeError(
#    1023         "Attempted to send an async request with a sync Client instance."
#    1024     )
#    1026 with request_context(request=request):
# -> 1027     response = transport.handle_request(request)
#    1029 assert isinstance(response.stream, SyncByteStream)
#    1031 response.request = request
#
# File ~/Thesis_project/.venv_Master/lib/python3.11/site-packages/httpx/_transports/default.py:236, in HTTPTransport.handle_request(self, request)
#     223 req = httpcore.Request(
#     224     method=request.method,
#     225     url=httpcore.URL(
#    (...)
#     233     extensions=request.extensions,
#     234 )
#     235 with map_httpcore_exceptions():
# --> 236     resp = self._pool.handle_request(req)
#     238 assert isinstance(resp.stream, typing.Iterable)
#     240 return Response(
#     241     status_code=resp.status,
#     242     headers=resp.headers,
#     243     stream=ResponseStream(resp.stream),
#     244     extensions=resp.extensions,
#     245 )
#
# File ~/Thesis_project/.venv_Master/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/Thesis_project/.venv_Master/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/Thesis_project/.venv_Master/lib/python3.11/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/Thesis_project/.venv_Master/lib/python3.11/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/Thesis_project/.venv_Master/lib/python3.11/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/Thesis_project/.venv_Master/lib/python3.11/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/Thesis_project/.venv_Master/lib/python3.11/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/Thesis_project/.venv_Master/lib/python3.11/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:
